# %% [markdown]
# THỰC HÀNH TRỰC QUAN HÓA DỮ LIỆU NÂNG CAO

# %%
import seaborn as sns
import pandas as pd 

microbiome = pd.read_csv("C:\\Users\\DELL\\Documents\\microbiome.csv")
sns.pairplot(data = microbiome, kind="scatter", hue = 'Taxon')

# %%
baseball = pd.read_csv("C:\\Users\\DELL\\Documents\\baseball.csv")
B = sns.pairplot(data = baseball, kind="hist")

# %%
#Giải thích code
#data: Khung dữ liệu gọn gàng (dạng dài) trong đó mỗi cột là một biến và mỗi hàng là một quan sát.
#kind(hist, kde, scatter, reg): Kiểu của plot
#hue: Đổi màu các biến
